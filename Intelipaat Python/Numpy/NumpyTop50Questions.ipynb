# %%
import numpy as np

# %%
a = [1,2,4,6,8,10,11, 13, 15, 17,19,20]
arr_1 = np.array(a)
# Out:
# dtype('int64')

# %%
np.ndarray((2,2), int)
# Out:
# array([[      108270645,               0],
#        [              1, 139641919742560]])
