# %%
- www.google.com
- search annaconda 
- Go to the anaconda website
- Download the annaconda
- Once the download part is done, run the file 
- Once you are run the file 
- select Just me, after that dnt select the enviorment rest you can select 
- once the installation is done 
- Go to the search bar and search for anaconda navigator 
- Click on anaconda navigator and search jyputer notebook and click on launch 
- Once clicking on lauch it will direct you to the google chrome 
- Click on new and make a folder and rename it by clicking on the checkbox 
- Once renaming it click on the folder and open it 
- Once it is opened than click on new and open python 3 Ipykernel file 
- And once the file is opened you can rename it by clicking on untitled

# %%
Heading ---> ctl +/ --> esc + m --> shift +enter
commenting ----> ctl + /
running the cell ---> shift + enter

# %% [markdown]
# # Python

# %%
- Python is a programming language which is both procedural and object
oriented programming 
- It is quit popular because is the best packages for AI and ML
- It is fast
- It is dynamic 
- Python is case sensitive 
- Python is extensively used in industries 
- Easy to learn 
- Friendly
- It is platform independent

# %%
a = 10 
print(a)
# Out:
# 10

# %%
F = 10 
print(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/54/7drcjbnx69957mm687ynr9x80000gn/T/ipykernel_1564/3973543519.py in <module>
#       1 F = 10
# ----> 2 print(f)
#
# NameError: name 'f' is not defined

# %% [markdown]
# # Variables or Identifiers

# %%
a = 10 
b = 20

# %% [markdown]
# # Rules for variable or Identifiers

# %%
- It can be any alphabet from a to z or A to Z or combination of smallcase or 
upper case or combination of numbers 
- It cannot start with a number 
- It cannot start with a special character except underscore
- It cannot be a keyword

# %%
a = 10 
print(a)
# Out:
# 10

# %%
A = 10 
print(A)
# Out:
# 10

# %%
aA = 10
print(aA)
# Out:
# 10

# %%
a1B=100
print(a1B)
# Out:
# 100

# %%
1abc = 100
print(1abc)
# Out:
#   File "/var/folders/54/7drcjbnx69957mm687ynr9x80000gn/T/ipykernel_1564/1811046798.py", line 1
#     1abc = 100
#      ^
# SyntaxError: invalid syntax

# %%
@abc = 100
print(@abc)
# Out:
#   File "/var/folders/54/7drcjbnx69957mm687ynr9x80000gn/T/ipykernel_1564/1260085229.py", line 1
#     @abc = 100
#          ^
# SyntaxError: invalid syntax

# %%
_abc= 100
print(_abc)
# Out:
# 100

# %%
a@bc = 100
print(a@bc)
# Out:
#   File "/var/folders/54/7drcjbnx69957mm687ynr9x80000gn/T/ipykernel_1564/2431449105.py", line 1
#     a@bc = 100
#     ^
# SyntaxError: cannot assign to operator

# %%
a_bc = 100
print(a_bc)
# Out:
# 100

# %% [markdown]
# # Keywords

# %%
- Keywords are the reserved words which cannot be used as a variable

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               break               for                 not
# None                class               from                or
# True                continue            global              pass
# __peg_parser__      def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield

# %%
false = 100
print(false)
# Out:
# 100

# %%
False = 100
print(False)
# Out:
#   File "/var/folders/54/7drcjbnx69957mm687ynr9x80000gn/T/ipykernel_2047/496908059.py", line 1
#     False = 100
#     ^
# SyntaxError: cannot assign to False

# %%
true = 100
print(true)
# Out:
# 100

# %%
True = 100
print(True)
# Out:
#   File "/var/folders/54/7drcjbnx69957mm687ynr9x80000gn/T/ipykernel_2047/639564904.py", line 1
#     True = 100
#     ^
# SyntaxError: cannot assign to True

# %%
a = 10 
b = 20 
c = 30

# %%
a,b,c = 10,20,30 
print(a,b,c)
# Out:
# 10 20 30

# %% [markdown]
# # Operators

# %%
- An operator serves as the keywords or symbols thats are used to
perform any operation

# %%
- Arithmetic operator
- Assignment operator
- Comparision Operator
- Logical Operator 
- Identity Operator 
- Membership Operator 
- Bitwise Operator

# %% [markdown]
# # Arithmetic Operator

# %%
a = 10 
b = 20 
c = a+b
print(c)
print(type(c))
print(id(c))
# Out:
# 30
# <class 'int'>
# 140570526883024

# %%
a = int(input("Enter the first number : "))
b = int(input("Enter the second number : "))
c = a+b
print(c)
print(type(c))
print(id(c))
# Out:
# Enter the first number : 4
# Enter the second number : 5
# 9
# <class 'int'>
# 140570526882352

# %%
a = 10 
print(id(a))
# Out:
# 140570526882384

# %%
b = 10 
print(id(b))
# Out:
# 140570526882384

# %%
# ADD
a = int(input("enter the first number :"))
b = int(input("enter the second number :"))
c = a+b
print(c)
print(type(c))
print (id(c))
# Out:
# enter the first number :8
# enter the second number :7
# 15
# <class 'int'>
# 140570526882544

# %%
# sub
a = int(input("enter the first number :"))
b = int(input("enter the second number :"))
c = a-b
print(c)
print(type(c))
print (id(c))
# Out:
# enter the first number :5
# enter the second number :3
# 2
# <class 'int'>
# 140570526882128

# %%
# div
a = int(input("enter the first number :"))
b = int(input("enter the second number :"))
c = a/b
print(c)
print(type(c))
print (id(c))
# Out:
# enter the first number :10
# enter the second number :2
# 5.0
# <class 'float'>
# 140570600311760

# %%
# mul
a = int(input("enter the first number :"))
b = int(input("enter the second number :"))
c = a*b
print(c)
print(type(c))
print (id(c))
# Out:
# enter the first number :10
# enter the second number :10
# 100
# <class 'int'>
# 140570527073744

# %%
# floor division - // ---> will give your quotient 

a = int(input("enter the first number :"))
b = int(input("enter the second number :"))
c = a//b
print(c)
# Out:
# enter the first number :20
# enter the second number :3
# 6

# %%
# modulus -- % ----  will give you remainder 
a = int(input("enter the first number :"))
b = int(input("enter the second number :"))
c = a%b
print(c)
# Out:
# enter the first number :20
# enter the second number :3
# 2

# %%
# power 
a = 10 
b = 2 

a ** b
# Out:
# 100

# %%
a = 10 
b = 3 

a ** b
# Out:
# 1000

# %% [markdown]
# # Assignment Operator

# %%
a = 10 
print(a)
# Out:
# 10

# %%
# a = a +10
a = 10 
a += 10 
print(a)
# Out:
# 20

# %%
a = 10 
a -= 10 
print(a)
# Out:
# 0

# %%
a = 10 
a /= 10 
print(a)
# Out:
# 1.0

# %%
a = 10 
a *= 10 
print(a)
# Out:
# 100

# %%
a = 10 
a //= 10 
print(a)
# Out:
# 1

# %%
a = 10 
a %= 10 
print(a)
# Out:
# 0

# %%
a = 10 
a **= 3 
print(a)
# Out:
# 1000

# %% [markdown]
# # Comparision Operator

# %%
a = 10 
b = 20 
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a = 'this is my python class'
print(a)
print(type(a))
# Out:
# this is my python class
# <class 'str'>

# %%
a = "this is my python class"
print(a)
print(type(a))
# Out:
# this is my python class
# <class 'str'>

# %%
a = '''this is my python class'''
print(a)
print(type(a))
# Out:
# this is my python class
# <class 'str'>

# %% [markdown]
# # Single Line statement

# %%
a = 'This is my python class .I am studying properly in the class'
print(a)
# Out:
# This is my python class .I am studying properly in the class

# %%
a = "This is my python class .I am studying properly in the class"
print(a)
# Out:
# This is my python class .I am studying properly in the class

# %%
a = '''This is my python class .I am studying properly in the class'''
print(a)
# Out:
# This is my python class .I am studying properly in the class

# %% [markdown]
# # Multi Line statement

# %%
a = 'This is my python class.
I am studying properly in the class'
print(a)
# Out:
#   File "/var/folders/54/7drcjbnx69957mm687ynr9x80000gn/T/ipykernel_2047/3403616286.py", line 1
#     a = 'This is my python class.
#                                  ^
# SyntaxError: EOL while scanning string literal

# %%
a = "This is my python class.
I am studying properly in the class"
print(a)
# Out:
#   File "/var/folders/54/7drcjbnx69957mm687ynr9x80000gn/T/ipykernel_2047/3075319245.py", line 1
#     a = "This is my python class.
#                                  ^
# SyntaxError: EOL while scanning string literal

# %%
a = '''This is my python class.
I am studying properly in the class'''
print(a)
# Out:
# This is my python class.
# I am studying properly in the class

# %%
a = ' This is my python's class.'
print(a)
# Out:
#   File "/var/folders/54/7drcjbnx69957mm687ynr9x80000gn/T/ipykernel_2047/2827452747.py", line 1
#     a = ' This is my python's class.'
#                             ^
# SyntaxError: invalid syntax

# %%
a = "This is my python's class."
print(a)
# Out:
# This is my python's class.
